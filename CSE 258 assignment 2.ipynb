# %% [markdown]
# ## Build predictions using Amazon Fine Food Reviews

# %%
import sqlite3
import pandas as pd
import numpy as np
import nltk
import string
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from nltk.stem.porter import PorterStemmer

# %%
from urllib.request import urlopen
from math import *

# %%
print ("Reading data...")
data = list(parseData("http://jmcauley.ucsd.edu/cse255/data/beer/beer_50000.json"))
print ("done")
# Out:
# Reading data...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fa321cc217da> in <module>()
#       1 print ("Reading data...")
# ----> 2 data = list(parseData("http://jmcauley.ucsd.edu/cse255/data/beer/beer_50000.json"))
#       3 print ("done")
#
# NameError: name 'parseData' is not defined

# %%
con = sqlite3.connect('C:/Users/Yang Xu/Documents/258 assignmengt 2/database.sqlite')

# %%
con

# %%
messages = pd.read_sql_query("""
SELECT Score, Summary
FROM Reviews
WHERE Score != 3
""", con)

def partition(x):
    if x < 3:
        return 'negative'
    return 'positive'

Score = messages['Score']
Score = Score.map(partition)
Summary = messages['Summary']
X_train, X_test, y_train, y_test = train_test_split(Summary, Score, test_size=0.2, random_state=42)

# %%
messages
# Out:
#         Score                                            Summary
# 0           5                              Good Quality Dog Food
# 1           1                                  Not as Advertised
# 2           4                              "Delight" says it all
# 3           2                                     Cough Medicine
# 4           5                                        Great taffy
# 5           4                                         Nice Taffy
# 6           5      Great!  Just as good as the expensive brands!
# 7           5                             Wonderful, tasty taffy
# 8           5                                         Yay Barley
# 9           5                                   Healthy Dog Food
# 10          5                    The Best Hot Sauce in the World
# 11          5  My cats LOVE this "diet" food better than thei...
# 12          1               My Cats Are Not Fans of the New Food
# 13          4                                  fresh and greasy!
# 14          5                       Strawberry Twizzlers - Yummy
# 15          5           Lots of twizzlers, just what you expect.
# 16          2                                         poor taste
# 17          5                                           Love it!
# 18          5                                 GREAT SWEET CANDY!
# 19          5                            Home delivered twizlers
# 20          5                                       Always fresh
# 21          5                                          TWIZZLERS
# 22          5                                 Delicious product!
# 23          5                                          Twizzlers
# 24          5                      Please sell these in Mexico!!
# 25          5                             Twizzlers - Strawberry
# 26          1                                    Nasty No flavor
# 27          4                        Great Bargain for the Price
# 28          5                                             YUMMY!
# 29          5                    The Best Hot Sauce in the World
# ...       ...                                                ...
# 525784      5                   Unusual, even for a violet candy
# 525785      5                                          Very good
# 525786      1                                            rip off
# 525787      5                              The search has ended!
# 525788      5                                         very tasty
# 525789      5                           Violet French Hard Candy
# 525790      5                                          delicious
# 525791      1                                       Mostly water
# 525792      1                                            No Good
# 525793      1                                   Tastes horrible!
# 525794      2                                        Not so good
# 525795      2                            Where's the tortellini?
# 525796      5                     Baker's Ammonia Small quantity
# 525797      5                                          Good buy.
# 525798      5                          Baking Ammonia that Works
# 525799      4                                               a-ok
# 525800      5    Delicious, all natural and allergy free treats!
# 525801      5                            Great For Fast Gulasch!
# 525802      5                                   Great Cafe Latte
# 525803      5                                      Excellent Tea
# 525804      5                     Best Value for Chinese 5 Spice
# 525805      5                                  Five Spice Powder
# 525806      2                                        Mixed wrong
# 525807      5  If its all natural, this is like panacea of Sp...
# 525808      5                      Very large ground spice jars.
# 525809      5                                Will not do without
# 525810      2                                       disappointed
# 525811      5                           Perfect for our maltipoo
# 525812      5                 Favorite Training and reward treat
# 525813      5                                        Great Honey
#
# [525814 rows x 2 columns]

# %%
messages.shape
messages.head(5)
# Out:
#    Score                Summary
# 0      5  Good Quality Dog Food
# 1      1      Not as Advertised
# 2      4  "Delight" says it all
# 3      2         Cough Medicine
# 4      5            Great taffy
